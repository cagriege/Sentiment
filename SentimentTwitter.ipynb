# %%
# Import Libraries
from textblob import TextBlob
import sys
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import nltk
import pycountry
import re
import string
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Authentication
consumerKey = "CsmUjIxi33uCl9j1qJso2Im7V"
consumerSecret = "6XNeKEMnN9EosLom164d45fIcnPHEE78MxE9eXfDqUC7dsNP1M"
accessToken = "2427637045-T7hwJyklGFtytCrQaEHLUevdxlCh842UQQfNjyK"
accessTokenSecret = "nhUgg9pE3YqleCj2mr6UMIphlWaRzdehUOpJQXctLsB7P"
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

# %%
#Sentiment Analysis
def percentage(part,whole):
 return 100 * float(part)/float(whole)
keyword = input("Please enter keyword or hashtag to search: ")
noOfTweet = int(input ("Please enter how many tweets to analyze: "))
tweets = tweepy.Cursor(api.search, q=keyword).items(noOfTweet)
positive = 0
negative = 0
neutral = 0
polarity = 0
tweet_list = []
neutral_list = []
negative_list = []
positive_list = []
for tweet in tweets:
 
 #print(tweet.text)
 tweet_list.append(tweet.text)
 analysis = TextBlob(tweet.text)
 score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
 neg = score['neg']
 neu = score['neu']
 pos = score['pos']
 comp = score['compound']
 polarity += analysis.sentiment.polarity
 
 if neg > pos:
     negative_list.append(tweet.text)
     negative += 1
 elif pos > neg:
     positive_list.append(tweet.text)
     positive += 1
 
 elif pos == neg:
     neutral_list.append(tweet.text)
 neutral += 1
positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negative = format(negative, '.1f')
neutral = format(neutral, '.1f')
# Out:
# Please enter keyword or hashtag to search: Recep Tayyip Erdoğan
# Please enter how many tweets to analyze: 50

# %%
#Number of Tweets (Total, Positive, Negative, Neutral)
tweet_list = pd.DataFrame(tweet_list)
neutral_list = pd.DataFrame(neutral_list)
negative_list = pd.DataFrame(negative_list)
positive_list = pd.DataFrame(positive_list)
print("total number: ",len(tweet_list))
print("positive number: ",len(positive_list))
print("negative number: ", len(negative_list))
print("neutral number: ",len(neutral_list))
# Out:
# total number:  50
# positive number:  2
# negative number:  1
# neutral number:  47

# %%
#Creating PieCart
labels = ['Positive ['+str(positive)+'%]' , 'Neutral ['+str(neutral)+'%]','Negative ['+str(negative)+'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'blue','red']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for keyword= "+keyword+"" )
plt.axis('equal')
plt.show()

# %%
tweet_list
# Out:
#                                                     0
# 0   Recep Tayyip Erdoğan İBB başkanı değil cumhurb...
# 1   RT @_gzd_avc253648: Bugüne kadar kime boyun eğ...
# 2   RT @kulistanbull: Dün:\nFOX TV: “Tam kapanma ş...
# 3   RT @Blrcan_0o_: Bugüne kadar kime boyun eğdik?...
# 4   RT @aysekesir: Vesayet odaklarına, Cumhurbaşka...
# 5   RT @_umran_bst962: Bugüne kadar kime boyun eğd...
# 6   RT @__Asalet_34: Sadece Makam için Sadece Nefs...
# 7   RT @Aydnmermerci: #EskiTürkiyeDeğiliz\nBütün A...
# 8   RT @06Afsar: Başkan Recep Tayyip Erdoğan Kabin...
# 9   Turkey’s President Recep Tayyip Erdogan has de...
# 10  RT @muhammedavci53: Hayaller Recep Tayyip Erdo...
# 11  RT @akpartiistanbul: İl Başkanımızın haftalık ...
# 12  RT @aysekesir: Vesayet odaklarına, Cumhurbaşka...
# 13  RT @aysgl__2023: Gelişmiş ülkelerden silah dil...
# 14  RT @bilal82520312: Yardımını Esirgeme YaRabbi ...
# 15  RT @aysekesir: Vesayet odaklarına, Cumhurbaşka...
# 16  RT @NeneHat73918708: Gelişmiş ülkelerden silah...
# 17  And #Sofagate is not over ... but maybe maybe ...
# 18  RT @NLGNMANAV1: Bugüne kadar kime boyun eğdik?...
# 19  RT @kulistanbull: Dün:\nFOX TV: “Tam kapanma ş...
# 20  RT @SaraykentK: AK Parti İlçe  Kadın Kolları B...
# 21  RT @06Afsar: Başkan Recep Tayyip Erdoğan Kabin...
# 22  RT @aysekesir: Vesayet odaklarına, Cumhurbaşka...
# 23  RT @juliahahntv: "I felt hurt and left alone, ...
# 24  RT @reiscisezo: Kardak kayalıklarına bayrak di...
# 25  RT @NLGNMANAV1: Bugüne kadar kime boyun eğdik?...
# 26  RT @aysekesir: Vesayet odaklarına, Cumhurbaşka...
# 27  RT @aysegul_gullu_: Bugüne kadar kime boyun eğ...
# 28  RT @Med_Muhtari: Aynı basın toplantısında Hem ...
# 29  RT @sarikocmurat: #eskitürkiyedeğiliz Elhâmdul...
# 30  RT @SekerSaduman: Genel Başkanımız ve Cumhurba...
# 31  RT @aysekesir: Vesayet odaklarına, Cumhurbaşka...
# 32  RT @Akparti: Cumhurbaşkanımız Recep Tayyip Erd...
# 33  RT @muhammedavci53: Hayaller Recep Tayyip Erdo...
# 34  RT @jsarieroglu: Cumhurbaşkanımız Sayın Recep ...
# 35  RT @Blrcan_0o_: Bugüne kadar kime boyun eğdik?...
# 36  RT @aysgl__2023: Gelişmiş ülkelerden silah dil...
# 37  RT @2023_Rtelice: 25 kuruşluk poşete, bir lira...
# 38  RT @jsarieroglu: Cumhurbaşkanımız Sayın Recep ...
# 39  RT @Blrcan_0o_: Bugüne kadar kime boyun eğdik?...
# 40  RT @salih_ekinci: AK Parti Genel Başkanımız ve...
# 41  RT @Hseyini67648111: "Karşınızda ne Osmanlı'nı...
# 42  RT @Med_Muhtari: Aynı basın toplantısında Hem ...
# 43  RT @2023_Rtelice: 25 kuruşluk poşete, bir lira...
# 44  RT @Aydnmermerci: Yâ Rabbi\nHer alanda her pla...
# 45  RT @Blrcan_0o_: Bugüne kadar kime boyun eğdik?...
# 46  RT @Akparti: Cumhurbaşkanımız Recep Tayyip Erd...
# 47  RT @Akkadinyozgat: İl Kadın Kolları Yönetim Ku...
# 48  RT @aysekesir: Vesayet odaklarına, Cumhurbaşka...
# 49  RT @aysekesir: Vesayet odaklarına, Cumhurbaşka...

# %%
negative_list

# %%
tweet_list.drop_duplicates(inplace = True)

# %%
#Cleaning Text (RT, Punctuation etc)
#Creating new dataframe and new features
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]
#Removing RT, Punctuation etc
remove_rt = lambda x: re.sub('RT @\w+: '," ",x)
rt = lambda x: re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x)
tw_list["text"] = tw_list.text.map(remove_rt).map(rt)
tw_list["text"] = tw_list.text.str.lower()
tw_list.head(50)
